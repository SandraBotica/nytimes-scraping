# %%
# Dependencies
import requests
from pprint import pprint
from config import api_key
import time

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
# Search for articles that mention pilates
query = "pilates"

# %%
# Build query URL
query_url = url + "api-key=" + api_key + "&q=" + query

# %%
# Request articles
articles = requests.get(query_url).json()

# The "response" property in articles contains the actual articles
# list comprehension.
articles_list = articles["response"]["docs"]
pprint(articles_list)
# Out:
# [{'_id': 'nyt://article/5ef68820-e975-5214-86f5-9986d126c0f8',
#   'abstract': 'Long after the death of Joseph Pilates, the exercise program’s '
#               'magnetic founder, his disciples are battling over his legacy.',
#   'byline': {'organization': None,
#              'original': 'By Katherine Rosman',
#              'person': [{'firstname': 'Katherine',
#                          'lastname': 'Rosman',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'The Fight for the Soul of Pilates',
#                'name': None,
#                'print_headline': 'A Legal Dispute Contorts the Pilates World',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N', 'name': 'subject', 'rank': 1, 'value': 'Pilates'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 2,
#                 'value': 'internal-sub-only'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'Social Media'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 4,
#                 'value': 'Copyrights and Copyright Violations'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 5,
#                 'value': 'Instagram Inc'},
#                {'major': 'N',
#                 'name': 'persons',
#                 'rank': 6,
#                 'value': 'Pilates, Joseph'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 7,
#                 'value': 'Suits and Litigation (Civil)'},
#                {'major': 'N',
#                 'name': 'persons',
#                 'rank': 8,
#                 'value': 'Gallagher, Sean P (Physical Therapist)'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 9,
#                 'value': 'audio-neutral-immersive'}],
#   'lead_paragraph': 'Joseph Pilates believed he had created an exercise '
#                     'program that would stand the test of time and contribute '
#                     'to the well-being of anyone who practiced it seriously. '
#                     'And while Pilates continues to grow in popularity 55 '
#                     'years after his death, many of its devotees are far from '
#                     'content, as they quarrel over his legacy.',
#   'multimedia': [{'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleLarge',
#                   'height': 900,
#                   'legacy': {'xlarge': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-articleLarge.jpg',
#                              'xlargeheight': 900,
#                              'xlargewidth': 600},
#                   'rank': 0,
#                   'subType': 'xlarge',
#                   'subtype': 'xlarge',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-articleLarge.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'popup',
#                   'height': 500,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'popup',
#                   'subtype': 'popup',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-popup.jpg',
#                   'width': 334},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog480',
#                   'height': 720,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog480',
#                   'subtype': 'blog480',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-blog480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog533',
#                   'height': 799,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog533',
#                   'subtype': 'blog533',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-blog533.jpg',
#                   'width': 533},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog427',
#                   'height': 640,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog427',
#                   'subtype': 'blog427',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-blog427.jpg',
#                   'width': 427},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagSF',
#                   'height': 543,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagSF',
#                   'subtype': 'tmagSF',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-tmagSF.jpg',
#                   'width': 362},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagArticle',
#                   'height': 888,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagArticle',
#                   'subtype': 'tmagArticle',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-tmagArticle.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'slide',
#                   'height': 500,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'slide',
#                   'subtype': 'slide',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-slide.jpg',
#                   'width': 334},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'jumbo',
#                   'height': 1024,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'jumbo',
#                   'subtype': 'jumbo',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-jumbo.jpg',
#                   'width': 684},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'superJumbo',
#                   'height': 2048,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'superJumbo',
#                   'subtype': 'superJumbo',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-superJumbo.jpg',
#                   'width': 1367},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog225',
#                   'height': 337,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog225',
#                   'subtype': 'blog225',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-blog225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master1050',
#                   'height': 1574,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master1050',
#                   'subtype': 'master1050',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-master1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master675',
#                   'height': 1012,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master675',
#                   'subtype': 'master675',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-master675.jpg',
#                   'width': 675},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master495',
#                   'height': 742,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master495',
#                   'subtype': 'master495',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-master495.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master180',
#                   'height': 270,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master180',
#                   'subtype': 'master180',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-master180.jpg',
#                   'width': 180},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master315',
#                   'height': 472,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master315',
#                   'subtype': 'master315',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-master315.jpg',
#                   'width': 315},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master768',
#                   'height': 1151,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master768',
#                   'subtype': 'master768',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-master768.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbStandard',
#                   'height': 75,
#                   'legacy': {'thumbnail': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-thumbStandard.jpg',
#                              'thumbnailheight': 75,
#                              'thumbnailwidth': 75},
#                   'rank': 0,
#                   'subType': 'thumbnail',
#                   'subtype': 'thumbnail',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-thumbStandard.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallThumb',
#                   'subtype': 'blogSmallThumb',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-blogSmallThumb.jpg',
#                   'width': 50},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbLarge',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'thumbLarge',
#                   'subtype': 'thumbLarge',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-thumbLarge.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'smallSquare168',
#                   'height': 168,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'smallSquare168',
#                   'subtype': 'smallSquare168',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-smallSquare168.jpg',
#                   'width': 168},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'smallSquare252',
#                   'height': 252,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'smallSquare252',
#                   'subtype': 'smallSquare252',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-smallSquare252.jpg',
#                   'width': 252},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'square320',
#                   'height': 320,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'square320',
#                   'subtype': 'square320',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-square320.jpg',
#                   'width': 320},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'moth',
#                   'height': 151,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'moth',
#                   'subtype': 'moth',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-moth.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'filmstrip',
#                   'height': 190,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'filmstrip',
#                   'subtype': 'filmstrip',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-filmstrip.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'square640',
#                   'height': 640,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'square640',
#                   'subtype': 'square640',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-square640.jpg',
#                   'width': 640},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumSquare149',
#                   'height': 149,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumSquare149',
#                   'subtype': 'mediumSquare149',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-mediumSquare149.jpg',
#                   'width': 149},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumSquareAt3X',
#                   'height': 1802,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumSquareAt3X',
#                   'subtype': 'mediumSquareAt3X',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-mediumSquareAt3X.jpg',
#                   'width': 1800},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'sfSpan',
#                   'height': 264,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'sfSpan',
#                   'subtype': 'sfSpan',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-sfSpan.jpg',
#                   'width': 395},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeHorizontal375',
#                   'height': 250,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeHorizontal375',
#                   'subtype': 'largeHorizontal375',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-largeHorizontal375.jpg',
#                   'width': 375},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeHorizontalJumbo',
#                   'height': 683,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeHorizontalJumbo',
#                   'subtype': 'largeHorizontalJumbo',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-largeHorizontalJumbo.jpg',
#                   'width': 1024},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'horizontalMediumAt2X',
#                   'height': 1335,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'horizontalMediumAt2X',
#                   'subtype': 'horizontalMediumAt2X',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-horizontalMediumAt2X.jpg',
#                   'width': 2001},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'hpLarge',
#                   'height': 288,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'hpLarge',
#                   'subtype': 'hpLarge',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-hpLarge.jpg',
#                   'width': 511},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeWidescreen573',
#                   'height': 322,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeWidescreen573',
#                   'subtype': 'largeWidescreen573',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-largeWidescreen573.jpg',
#                   'width': 573},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeWidescreen1050',
#                   'height': 591,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeWidescreen1050',
#                   'subtype': 'largeWidescreen1050',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-largeWidescreen1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbWide',
#                   'height': 126,
#                   'legacy': {'wide': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-thumbWide.jpg',
#                              'wideheight': 126,
#                              'widewidth': 190},
#                   'rank': 0,
#                   'subType': 'wide',
#                   'subtype': 'wide',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-thumbWide.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoThumb',
#                   'subtype': 'videoThumb',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoThumb.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoLarge',
#                   'height': 507,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoLarge',
#                   'subtype': 'videoLarge',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoLarge.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo210',
#                   'height': 140,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo210',
#                   'subtype': 'mediumThreeByTwo210',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-mediumThreeByTwo210.jpg',
#                   'width': 210},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo225',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo225',
#                   'subtype': 'mediumThreeByTwo225',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-mediumThreeByTwo225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo440',
#                   'height': 293,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo440',
#                   'subtype': 'mediumThreeByTwo440',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-mediumThreeByTwo440.jpg',
#                   'width': 440},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo252',
#                   'height': 168,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo252',
#                   'subtype': 'mediumThreeByTwo252',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-mediumThreeByTwo252.jpg',
#                   'width': 252},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo378',
#                   'height': 252,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo378',
#                   'subtype': 'mediumThreeByTwo378',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-mediumThreeByTwo378.jpg',
#                   'width': 378},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoLargeAt2X',
#                   'height': 1335,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoLargeAt2X',
#                   'subtype': 'threeByTwoLargeAt2X',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-threeByTwoLargeAt2X.jpg',
#                   'width': 2001},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoMediumAt2X',
#                   'height': 1001,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoMediumAt2X',
#                   'subtype': 'threeByTwoMediumAt2X',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-threeByTwoMediumAt2X.jpg',
#                   'width': 1500},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'threeByTwoSmallAt2X',
#                   'height': 400,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'threeByTwoSmallAt2X',
#                   'subtype': 'threeByTwoSmallAt2X',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-threeByTwoSmallAt2X.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleInline',
#                   'height': 285,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'articleInline',
#                   'subtype': 'articleInline',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-articleInline.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'hpSmall',
#                   'height': 244,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'hpSmall',
#                   'subtype': 'hpSmall',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-hpSmall.jpg',
#                   'width': 163},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallInline',
#                   'height': 226,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallInline',
#                   'subtype': 'blogSmallInline',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-blogSmallInline.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumFlexible177',
#                   'height': 265,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumFlexible177',
#                   'subtype': 'mediumFlexible177',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-mediumFlexible177.jpg',
#                   'width': 177},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSmall',
#                   'height': 281,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSmall',
#                   'subtype': 'videoSmall',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoSmall.jpg',
#                   'width': 500},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoHpMedium',
#                   'height': 211,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoHpMedium',
#                   'subtype': 'videoHpMedium',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoHpMedium.jpg',
#                   'width': 375},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine600',
#                   'height': 338,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine600',
#                   'subtype': 'videoSixteenByNine600',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoSixteenByNine600.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine540',
#                   'height': 304,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine540',
#                   'subtype': 'videoSixteenByNine540',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoSixteenByNine540.jpg',
#                   'width': 540},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine495',
#                   'height': 278,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine495',
#                   'subtype': 'videoSixteenByNine495',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoSixteenByNine495.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine390',
#                   'height': 219,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine390',
#                   'subtype': 'videoSixteenByNine390',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoSixteenByNine390.jpg',
#                   'width': 390},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine1050',
#                   'height': 591,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine1050',
#                   'subtype': 'videoSixteenByNine1050',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoSixteenByNine1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine480',
#                   'height': 270,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine480',
#                   'subtype': 'videoSixteenByNine480',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoSixteenByNine480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine310',
#                   'height': 174,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine310',
#                   'subtype': 'videoSixteenByNine310',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoSixteenByNine310.jpg',
#                   'width': 310},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine225',
#                   'height': 126,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine225',
#                   'subtype': 'videoSixteenByNine225',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoSixteenByNine225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine96',
#                   'height': 54,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine96',
#                   'subtype': 'videoSixteenByNine96',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoSixteenByNine96.jpg',
#                   'width': 96},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine768',
#                   'height': 432,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine768',
#                   'subtype': 'videoSixteenByNine768',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoSixteenByNine768.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine150',
#                   'height': 84,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine150',
#                   'subtype': 'videoSixteenByNine150',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoSixteenByNine150.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNineJumbo1600',
#                   'height': 900,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNineJumbo1600',
#                   'subtype': 'videoSixteenByNineJumbo1600',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoSixteenByNineJumbo1600.jpg',
#                   'width': 1600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'miniMoth',
#                   'height': 70,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'miniMoth',
#                   'subtype': 'miniMoth',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-miniMoth.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'windowsTile336H',
#                   'height': 336,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'windowsTile336H',
#                   'subtype': 'windowsTile336H',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-windowsTile336H.jpg',
#                   'width': 694},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoFifteenBySeven1305',
#                   'height': 609,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoFifteenBySeven1305',
#                   'subtype': 'videoFifteenBySeven1305',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-videoFifteenBySeven1305.jpg',
#                   'width': 1305},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'facebookJumbo',
#                   'height': 550,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'facebookJumbo',
#                   'subtype': 'facebookJumbo',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-facebookJumbo.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch308',
#                   'height': 348,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch308',
#                   'subtype': 'watch308',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-watch308.jpg',
#                   'width': 312},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch268',
#                   'height': 304,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch268',
#                   'subtype': 'watch268',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-watch268.jpg',
#                   'width': 272},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'verticalTwoByThree735',
#                   'height': 1102,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'verticalTwoByThree735',
#                   'subtype': 'verticalTwoByThree735',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-verticalTwoByThree735.jpg',
#                   'width': 735},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mobileMasterAt3x',
#                   'height': 2699,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mobileMasterAt3x',
#                   'subtype': 'mobileMasterAt3x',
#                   'type': 'image',
#                   'url': 'images/2022/10/16/fashion/PILATES-02/PILATES-02-mobileMasterAt3x.jpg',
#                   'width': 1800}],
#   'news_desk': 'Styles',
#   'print_page': '14',
#   'print_section': 'ST',
#   'pub_date': '2022-10-14T15:45:03+0000',
#   'section_name': 'Style',
#   'snippet': 'Long after the death of Joseph Pilates, the exercise program’s '
#              'magnetic founder, his disciples are battling over his legacy.',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/5ef68820-e975-5214-86f5-9986d126c0f8',
#   'web_url': 'https://www.nytimes.com/2022/10/14/style/the-fight-for-the-soul-of-pilates-moves-from-instagram-to-court.html',
#   'word_count': 2887},
#  {'_id': 'nyt://article/a5956f1e-e2d1-51d7-9038-5352b360b427',
#   'abstract': 'The strength and flexibility workout is having a moment. What '
#               'can — and can’t — it do for us?',
#   'byline': {'organization': None,
#              'original': 'By Danielle Friedman',
#              'person': [{'firstname': 'Danielle',
#                          'lastname': 'Friedman',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': 'Why not try',
#                'main': 'Is Pilates as Good as Everyone Says?',
#                'name': None,
#                'print_headline': 'Pilates Offers an Array of Health Benefits',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N', 'name': 'subject', 'rank': 1, 'value': 'Pilates'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 2,
#                 'value': 'Health Clubs'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'Exercise'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 4,
#                 'value': 'Physical Therapy'},
#                {'major': 'N', 'name': 'subject', 'rank': 5, 'value': 'Pain'},
#                {'major': 'N', 'name': 'subject', 'rank': 6, 'value': 'Muscles'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 7,
#                 'value': 'audio-positive-happy'}],
#   'lead_paragraph': 'After Shari Berkowitz was injured during a live dance '
#                     'performance onstage, doctors told the actress that one '
#                     'wrong move could leave her paralyzed for life. She had '
#                     'suffered three herniated discs in her neck, with one '
#                     'bulging into her spinal column. Months of physical '
#                     'therapy got her out of the danger zone, and then she '
#                     'discovered Pilates.',
#   'multimedia': [{'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleLarge',
#                   'height': 900,
#                   'legacy': {'xlarge': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-articleLarge.jpg',
#                              'xlargeheight': 900,
#                              'xlargewidth': 600},
#                   'rank': 0,
#                   'subType': 'xlarge',
#                   'subtype': 'xlarge',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-articleLarge.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'popup',
#                   'height': 500,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'popup',
#                   'subtype': 'popup',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-popup.jpg',
#                   'width': 334},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog480',
#                   'height': 720,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog480',
#                   'subtype': 'blog480',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-blog480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog533',
#                   'height': 799,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog533',
#                   'subtype': 'blog533',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-blog533.jpg',
#                   'width': 533},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog427',
#                   'height': 640,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog427',
#                   'subtype': 'blog427',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-blog427.jpg',
#                   'width': 427},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagSF',
#                   'height': 543,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagSF',
#                   'subtype': 'tmagSF',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-tmagSF.jpg',
#                   'width': 362},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagArticle',
#                   'height': 888,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagArticle',
#                   'subtype': 'tmagArticle',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-tmagArticle.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'slide',
#                   'height': 500,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'slide',
#                   'subtype': 'slide',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-slide.jpg',
#                   'width': 334},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'jumbo',
#                   'height': 1024,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'jumbo',
#                   'subtype': 'jumbo',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-jumbo.jpg',
#                   'width': 683},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'superJumbo',
#                   'height': 2048,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'superJumbo',
#                   'subtype': 'superJumbo',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-superJumbo.jpg',
#                   'width': 1366},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog225',
#                   'height': 337,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog225',
#                   'subtype': 'blog225',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-blog225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master1050',
#                   'height': 1575,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master1050',
#                   'subtype': 'master1050',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-master1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master675',
#                   'height': 1012,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master675',
#                   'subtype': 'master675',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-master675.jpg',
#                   'width': 675},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master495',
#                   'height': 742,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master495',
#                   'subtype': 'master495',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-master495.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master180',
#                   'height': 270,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master180',
#                   'subtype': 'master180',
#                   'type': 'image',
#                   'url': 'images/2022/08/02/well/20WNT-PILATES-DONE-CORRECTLY2/merlin_210297378_7f5e9dfe-b9c0-496d-a6cf-b3ccee7439d1-master180.jpg',
#                   'width': 180},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master315',
#                   'height': 472,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master315',
#                   'subtype': 'master315',
#                   'type': 'image',
# ...
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog427',
#                   'height': 142,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog427',
#                   'subtype': 'blog427',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-blog427.jpg',
#                   'width': 427},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagArticle',
#                   'height': 197,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagArticle',
#                   'subtype': 'tmagArticle',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-tmagArticle.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'jumbo',
#                   'height': 197,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'jumbo',
#                   'subtype': 'jumbo',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-jumbo.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog225',
#                   'height': 75,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog225',
#                   'subtype': 'blog225',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-blog225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master180',
#                   'height': 60,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master180',
#                   'subtype': 'master180',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-master180.jpg',
#                   'width': 180},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'popup',
#                   'height': 197,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'popup',
#                   'subtype': 'popup',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-popup.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog533',
#                   'height': 177,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog533',
#                   'subtype': 'blog533',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-blog533.jpg',
#                   'width': 533},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagSF',
#                   'height': 120,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagSF',
#                   'subtype': 'tmagSF',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-tmagSF.jpg',
#                   'width': 362},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'slide',
#                   'height': 197,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'slide',
#                   'subtype': 'slide',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-slide.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'superJumbo',
#                   'height': 197,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'superJumbo',
#                   'subtype': 'superJumbo',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-superJumbo.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master495',
#                   'height': 165,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master495',
#                   'subtype': 'master495',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-master495.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'filmstrip',
#                   'height': 190,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'filmstrip',
#                   'subtype': 'filmstrip',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-filmstrip.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'moth',
#                   'height': 151,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'moth',
#                   'subtype': 'moth',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-moth.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleInline',
#                   'height': 63,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'articleInline',
#                   'subtype': 'articleInline',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-articleInline.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'hpSmall',
#                   'height': 54,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'hpSmall',
#                   'subtype': 'hpSmall',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-hpSmall.jpg',
#                   'width': 163},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallInline',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallInline',
#                   'subtype': 'blogSmallInline',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-blogSmallInline.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumFlexible177',
#                   'height': 59,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumFlexible177',
#                   'subtype': 'mediumFlexible177',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-mediumFlexible177.jpg',
#                   'width': 177},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'sfSpan',
#                   'height': 131,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'sfSpan',
#                   'subtype': 'sfSpan',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-sfSpan.jpg',
#                   'width': 395},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoHpMedium',
#                   'height': 190,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoHpMedium',
#                   'subtype': 'videoHpMedium',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-videoHpMedium.jpg',
#                   'width': 337},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbStandard',
#                   'height': 75,
#                   'legacy': {'thumbnail': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-thumbStandard.jpg',
#                              'thumbnailheight': 75,
#                              'thumbnailwidth': 75},
#                   'rank': 0,
#                   'subType': 'thumbnail',
#                   'subtype': 'thumbnail',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-thumbStandard.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbLarge',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'thumbLarge',
#                   'subtype': 'thumbLarge',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-thumbLarge.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallThumb',
#                   'subtype': 'blogSmallThumb',
#                   'type': 'image',
#                   'url': 'images/2013/08/09/health/09askwell_yoga/09askwell_yoga-blogSmallThumb.jpg',
#                   'width': 50}],
#   'news_desk': '',
#   'pub_date': '2013-08-09T15:23:40+0000',
#   'section_name': 'Health',
#   'snippet': 'The answer, Gretchen Reynolds notes, depends to a large degree '
#              'on what muscles you are trying to strengthen.',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/e246ff3c-1660-5bcc-b63b-221b952e1828',
#   'web_url': 'https://well.blogs.nytimes.com/2013/08/09/ask-well-pilates-vs-yoga/',
#   'word_count': 309},
#  {'_id': 'nyt://article/8f95e8a7-7999-5320-b54f-885a4530d108',
#   'abstract': 'Joy Puleo opens pilates exercise venue, Body Wise Pilates '
#               'Studio in Chappaqua, NY, across street from Half Moon, owned by '
#               'Michael Feigin and Lawson Harris; photo (S)',
#   'byline': {'organization': None,
#              'original': 'By Susan Hodara',
#              'person': [{'firstname': 'Susan',
#                          'lastname': 'Hodara',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': 'IN BUSINESS',
#                'main': 'In Chappaqua, Pilates On Both Sides of the Street',
#                'name': None,
#                'print_headline': 'IN BUSINESS; In Chappaqua, Pilates On Both '
#                                  'Sides of the Street',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'glocations',
#                 'rank': 1,
#                 'value': 'Chappaqua (NY)'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 2,
#                 'value': 'HALF MOON'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 3,
#                 'value': 'BODY WISE PILATES STUDIO'},
#                {'major': 'N',
#                 'name': 'persons',
#                 'rank': 4,
#                 'value': 'PULEO, JOY'},
#                {'major': 'N',
#                 'name': 'persons',
#                 'rank': 5,
#                 'value': 'FEIGIN, MICHAEL'},
#                {'major': 'N',
#                 'name': 'persons',
#                 'rank': 6,
#                 'value': 'HARRIS, LAWSON'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 7,
#                 'value': 'Exercise'}],
#   'lead_paragraph': 'Is Chappaqua big enough for two new pilates studios? '
#                     'Apparently so, say Michael Feigin and Lawson Harris, the '
#                     'husband-and-wife team who own Half Moon, which opened in '
#                     'November, and Joy Puleo, owner of Body Wise Pilates '
#                     'Studio, which opened a few weeks later diagonally across '
#                     'King Street.',
#   'multimedia': [],
#   'news_desk': 'Westchester Weekly Desk',
#   'print_page': '14',
#   'print_section': 'WC',
#   'pub_date': '2002-02-03T05:00:00+0000',
#   'section_name': 'New York',
#   'snippet': 'Joy Puleo opens pilates exercise venue, Body Wise Pilates Studio '
#              'in Chappaqua, NY, across street from Half Moon, owned by Michael '
#              'Feigin and Lawson Harris; photo (S)',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/8f95e8a7-7999-5320-b54f-885a4530d108',
#   'web_url': 'https://www.nytimes.com/2002/02/03/nyregion/in-business-in-chappaqua-pilates-on-both-sides-of-the-street.html',
#   'word_count': 190},
#  {'_id': 'nyt://article/fdba9a87-96d9-5567-8dce-ec79fdf665f5',
#   'abstract': "W Safire on Pres Ford's admission that he misled press and "
#               'public in early Aug when he said he believed then-Pres Nixon '
#               "innocent in Watergate although he had learned of Nixon's guilt; "
#               'discusses alternatives Ford had; says in retrospect a better '
#               'case can be made for alternative of not commenting at all',
#   'byline': {'organization': None,
#              'original': 'By William Safire',
#              'person': [{'firstname': 'William',
#                          'lastname': 'Safire',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'Jesting Pilate',
#                'name': None,
#                'print_headline': 'Jesting Pilate',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'Watergate Affair'}],
#   'lead_paragraph': 'WASHINGTON—“‘What is truth?’ said jesting Pilate; and '
#                     'would not stay for an answer.”',
#   'multimedia': [],
#   'news_desk': 'None',
#   'print_page': '33',
#   'pub_date': '1974-10-21T05:00:00+0000',
#   'section_name': 'Archives',
#   'snippet': "W Safire on Pres Ford's admission that he misled press and "
#              'public in early Aug when he said he believed then-Pres Nixon '
#              "innocent in Watergate although he had learned of Nixon's guilt; "
#              'discusses alternatives Ford had; says in retrospect a better '
#              'ca...',
#   'source': 'The New York Times',
#   'type_of_material': 'Archives',
#   'uri': 'nyt://article/fdba9a87-96d9-5567-8dce-ec79fdf665f5',
#   'web_url': 'https://www.nytimes.com/1974/10/21/archives/jesting-pilate.html',
#   'word_count': 766}]

# %%
# Print the web_url of each stored article
print("Your Reading List")
for article in articles_list:
    print(article["web_url"])
# Out:
# Your Reading List
# https://www.nytimes.com/2022/10/14/style/the-fight-for-the-soul-of-pilates-moves-from-instagram-to-court.html
# https://www.nytimes.com/2022/07/22/well/move/pilates-exercise-flexibility.html
# https://www.nytimes.com/2013/02/01/nyregion/megaformer-workout-at-slt-studio.html
# https://www.nytimes.com/2022/04/25/style/forma-pilates-cost-exclusive.html
# https://cityroom.blogs.nytimes.com/2014/07/29/different-needs-at-pilates-class/
# https://www.nytimes.com/1998/11/03/health/the-novice-learning-pilates-one-stretch-at-a-time.html
# https://www.nytimes.com/1997/05/04/magazine/none-dare-call-it-pilates.html
# https://well.blogs.nytimes.com/2013/08/09/ask-well-pilates-vs-yoga/
# https://www.nytimes.com/2002/02/03/nyregion/in-business-in-chappaqua-pilates-on-both-sides-of-the-street.html
# https://www.nytimes.com/1974/10/21/archives/jesting-pilate.html

# %%
# Search for articles published between a begin and end date
begin_date = "20220101"
end_date = "20230630"

# %%
query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"

# %%
# Retrieve articles
articles = requests.get(query_url).json()
articles_list = articles["response"]["docs"]

for article in articles_list:
    print(f'A snippet from the article: {article["snippet"]}')
    print('---------------------------')
# Out:
# A snippet from the article: Long after the death of Joseph Pilates, the exercise program’s magnetic founder, his disciples are battling over his legacy.
# ---------------------------
# A snippet from the article: The strength and flexibility workout is having a moment. What can — and can’t — it do for us?
# ---------------------------
# A snippet from the article: Has inflation hit boutique fitness, or have workouts reached a new level of exclusivity?
# ---------------------------
# A snippet from the article: Asad Syrkett stays close to his Brooklyn home, doing Pilates, seeing friends, burning incense and reading fiction.
# ---------------------------
# A snippet from the article: The case of the $5,000 Bruce Springsteen tickets. Also in this edition: the hounds guarding U.S. agriculture, and why Pilates is having a moment.
# ---------------------------
# A snippet from the article: Back pain is common and complicated. But altering your workout to build control and stability can help prevent it.
# ---------------------------
# A snippet from the article: How scientists are redefining the second. Also in this edition: a writer hikes to a Canadian wilderness resort and Sheryl Crow tells her life story.
# ---------------------------
# A snippet from the article: Here’s what you need to know at the end of the day.
# ---------------------------
# A snippet from the article: This year, resolve to create a stable fitness routine out of whatever you enjoy most.
# ---------------------------
# A snippet from the article: Dan Caprera’s Thursday puzzle is a wild one.
# ---------------------------

# %%
import time

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param

# Empty list for articles
articles_list = []

# loop through pages 0-2
for page in range(0, 3):
    query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
    # create query with page number
    query_url = f"{query_url}&page={str(page)}"
    articles = requests.get(query_url).json()
    
    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    # loop through the response and append each article to the list
    for article in articles["response"]["docs"]:
        articles_list.append(article)

# %%
# Retrieve articles
articles = requests.get(query_url).json()
articles_list = articles["response"]["docs"]

for article in articles_list:
    print(f'A snippet from the article: {article["snippet"]}')
    print('---------------------------')
# Out:
# A snippet from the article: The actress is back for the final season of “The Good Fight.”
# ---------------------------
# A snippet from the article: To help ease you into the new year, and perhaps a new exercise routine, a roundup of lines offering clothes both functional and fashion-forward.
# ---------------------------
# A snippet from the article: Joseph DeRuvo Jr. has lived a mostly barefooted life for nearly two decades. The experience has given him a thick skin.
# ---------------------------
# A snippet from the article: The domestic diva talks about shedding her inhibitions, and (most of) her clothes, for the cover shoot.
# ---------------------------
# A snippet from the article: The founders of Yoga to the People, a once wildly successful business that closed in 2020, are accused of concealing their income from the Internal Revenue Service for years.
# ---------------------------
# A snippet from the article: Many countries across the globe are facing dangerously high temperatures. Here’s what to do to stay safe.
# ---------------------------
# A snippet from the article: The actress is a fan of the Black-owned mom-and-pop stores in the Bedford-Stuyvesant section of Brooklyn.
# ---------------------------
# A snippet from the article: Let’s pull apart Andrew Kingsley and Garrett Chalfin’s grid.
# ---------------------------
# A snippet from the article: Jessamine Chan’s “The School for Good Mothers” takes up themes of autonomy and technology in imagining an experimental facility where parents go through mandatory retraining.
# ---------------------------
# A snippet from the article: Batuman’s follow-up to “The Idiot” follows the same character into her second year at Harvard.
# ---------------------------
